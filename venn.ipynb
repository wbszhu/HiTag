# %% [markdown]
# <a href="https://colab.research.google.com/github/wbszhu/HiTag/blob/master/venn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install matplotlib-venn

# %%
from matplotlib_venn import venn2
from matplotlib import pyplot as plt
plt.figure(figsize=(4,4))
venn2(subsets = (9223, 14087, 108925), set_labels = ('CUT&Tag peak as ref.', '1D peak as ref.'))
plt.title("HiTag Loop(5kb:20kb-2Mb)")
plt.show()
